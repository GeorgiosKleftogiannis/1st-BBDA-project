# %%
print(7+3)
# Out:
# 10

# %%
a=7
b=3

# %%
a+b
# Out:
# 10

# %%
print(a%b)
# Out:
# 1

# %%
c=1.2
d=3.5

# %%
print(c+d)
# Out:
# 4.7

# %%
type(c)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
celcius_temperature=30
fahrenheit_temperature=(celcius_temperature*9/5)+32
print(fahrenheit_temperature)
# Out:
# 86.0
